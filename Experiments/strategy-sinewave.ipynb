# %%
import sys
sys.path.append("..")

from strategies.sinewave import strategy1

# %%
strategy1.train()
# Out:
# /usr/local/lib/python3.8/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Action Space: Discrete(2)
# State Space: (30, 5)
# Next observation
# {'internal': {'sine-wave:/USD-TTC': 146.52455186502817, 'sine-wave:/USD:/free': 100.0, 'sine-wave:/USD:/locked': 0.0, 'sine-wave:/USD:/total': 100.0, 'sine-wave:/TTC:/free': 0.0, 'sine-wave:/TTC:/locked': 0.0, 'sine-wave:/TTC:/total': 0.0, 'sine-wave:/TTC:/worth': 0.0, 'net_worth': 100.0}, 'external': {'sine-wave:/USD-TTC': 146.52455186502817, 'fast': 148.98060346336018, 'medium': 134.7272139760552, 'slow': 134.7272139760552, 'lr': -0.007189842104874167}, 'renderer': {'price': 146.52455186502817, 'action': 0}}
# Eval num_timesteps=1000, episode_reward=944.79 +/- 0.00
# Episode length: 470.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=944.22 +/- 0.00
# Episode length: 470.00 +/- 0.00
# ...

# %%
strategy1.evaluate()
# Out:
# /usr/local/lib/python3.8/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# episode_reward
# 543.239299434566
