# %%
import sys
sys.path.append("..")

from strategies.sinewave import strategy1

# %%
strategy1.train()
# Out:
# /usr/local/lib/python3.8/dist-packages/gym/logger.py:30: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize('%s: %s'%('WARN', msg % args), 'yellow'))
# Action Space: Discrete(2)
# State Space: (30, 5)
# Next observation
# {'internal': {'sine-wave:/USD-TTC': 127.55794406548502, 'sine-wave:/USD:/free': 100.0, 'sine-wave:/USD:/locked': 0.0, 'sine-wave:/USD:/total': 100.0, 'sine-wave:/TTC:/free': 0.0, 'sine-wave:/TTC:/locked': 0.0, 'sine-wave:/TTC:/total': 0.0, 'sine-wave:/TTC:/worth': 0.0, 'net_worth': 100.0}, 'external': {'sine-wave:/USD-TTC': 127.55794406548502, 'fast': 123.89302544617674, 'medium': 114.17100156139105, 'slow': 114.17100156139105, 'lr': 0.0062161309980997}, 'renderer': {'price': 127.55794406548502, 'action': 0}}
# Eval num_timesteps=1000, episode_reward=565.18 +/- 0.00
# Episode length: 970.00 +/- 0.00
# New best mean reward!
# Eval num_timesteps=2000, episode_reward=569.44 +/- 0.00
# Episode length: 970.00 +/- 0.00
# ...

# %%
import os
os.chdir("..")

# %%
strategy1.evaluate()

# %%
import os
os.chdir("..")

#to get the current working directory
directory = os.getcwd()

print(directory)
